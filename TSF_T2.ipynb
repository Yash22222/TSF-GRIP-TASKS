# %% [markdown]
# <a href="https://colab.research.google.com/github/Yash22222/TSF-GRIP-TASKS/blob/main/TSF_T2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The Sparks Foundation: Data Science & Business Analytics Internship #GRIPJUNE23

# %% [markdown]
# Exploratory Data Analysis - Terrorism (Level - Intermediate)
#
# Perform 'Exploratory Data Analysis' on dataset 'Global Terrorism'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("globalterrorismdb.csv", encoding="ISO-8859-1")

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# 0  Santo Domingo  18.456792  -69.951164          1.0         0      NaN
# 1    Mexico city  19.371887  -99.086624          1.0         0      NaN
# 2        Unknown  15.478598  120.599741          4.0         0      NaN
# 3         Athens  37.997490   23.762728          1.0         0      NaN
# 4        Fukouka  33.580412  130.396361          1.0         0      NaN
#
#   summary  crit1  crit2  crit3  doubtterr  alternative alternative_txt  \
# 0     NaN      1      1      1        0.0          NaN             NaN
# 1     NaN      1      1      1        0.0          NaN             NaN
# 2     NaN      1      1      1        0.0          NaN             NaN
# 3     NaN      1      1      1        0.0          NaN             NaN
# 4     NaN      1      1      1       -9.0          NaN             NaN
#
#    multiple  success  suicide  attacktype1                 attacktype1_txt  \
# 0       0.0        1        0            1                   Assassination
# 1       0.0        1        0            6     Hostage Taking (Kidnapping)
# 2       0.0        1        0            1                   Assassination
# 3       0.0        1        0            3               Bombing/Explosion
# 4       0.0        1        0            7  Facility/Infrastructure Attack
#
#    attacktype2 attacktype2_txt  attacktype3 attacktype3_txt  targtype1  \
# 0          NaN             NaN          NaN             NaN         14
# 1          NaN             NaN          NaN             NaN          7
# 2          NaN             NaN          NaN             NaN         10
# 3          NaN             NaN          NaN             NaN          7
# 4          NaN             NaN          NaN             NaN          7
#
#                  targtype1_txt  targsubtype1  \
# 0  Private Citizens & Property          68.0
# 1      Government (Diplomatic)          45.0
# 2          Journalists & Media          54.0
# 3      Government (Diplomatic)          46.0
# 4      Government (Diplomatic)          46.0
#
#                                     targsubtype1_txt  \
# 0                                     Named Civilian
# 1  Diplomatic Personnel (outside of embassy, cons...
# 2                    Radio Journalist/Staff/Facility
# 3                                  Embassy/Consulate
# 4                                  Embassy/Consulate
#
#                          corp1                  target1  natlty1  \
# 0                          NaN             Julio Guzman     58.0
# 1  Belgian Ambassador Daughter  Nadine Chaval, daughter     21.0
# 2             Voice of America                 Employee    217.0
# 3                          NaN             U.S. Embassy    217.0
# 4                          NaN           U.S. Consulate    217.0
#
#           natlty1_txt  targtype2 targtype2_txt  targsubtype2 targsubtype2_txt  \
# 0  Dominican Republic        NaN           NaN           NaN              NaN
# 1             Belgium        NaN           NaN           NaN              NaN
# 2       United States        NaN           NaN           NaN              NaN
# 3       United States        NaN           NaN           NaN              NaN
# 4       United States        NaN           NaN           NaN              NaN
#
#   corp2 target2  natlty2 natlty2_txt  targtype3 targtype3_txt  targsubtype3  \
# 0   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 1   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 2   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 3   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 4   NaN     NaN      NaN         NaN        NaN           NaN           NaN
#
#   targsubtype3_txt corp3 target3  natlty3 natlty3_txt  \
# 0              NaN   NaN     NaN      NaN         NaN
# 1              NaN   NaN     NaN      NaN         NaN
# 2              NaN   NaN     NaN      NaN         NaN
# 3              NaN   NaN     NaN      NaN         NaN
# 4              NaN   NaN     NaN      NaN         NaN
#
#                                 gname gsubname gname2 gsubname2 gname3  \
# 0                              MANO-D      NaN    NaN       NaN    NaN
# 1  23rd of September Communist League      NaN    NaN       NaN    NaN
# 2                             Unknown      NaN    NaN       NaN    NaN
# 3                             Unknown      NaN    NaN       NaN    NaN
# 4                             Unknown      NaN    NaN       NaN    NaN
#
#   gsubname3 motive  guncertain1  guncertain2  guncertain3  individual  nperps  \
# 0       NaN    NaN          0.0          NaN          NaN         0.0     NaN
# 1       NaN    NaN          0.0          NaN          NaN         0.0     7.0
# 2       NaN    NaN          0.0          NaN          NaN         0.0     NaN
# 3       NaN    NaN          0.0          NaN          NaN         0.0     NaN
# 4       NaN    NaN          0.0          NaN          NaN         0.0     NaN
#
#    nperpcap  claimed  claimmode claimmode_txt  claim2  claimmode2  \
# 0       NaN      NaN        NaN           NaN     NaN         NaN
# 1       NaN      NaN        NaN           NaN     NaN         NaN
# 2       NaN      NaN        NaN           NaN     NaN         NaN
# 3       NaN      NaN        NaN           NaN     NaN         NaN
# 4       NaN      NaN        NaN           NaN     NaN         NaN
#
#   claimmode2_txt  claim3  claimmode3 claimmode3_txt  compclaim  weaptype1  \
# 0            NaN     NaN         NaN            NaN        NaN       13.0
# 1            NaN     NaN         NaN            NaN        NaN       13.0
# 2            NaN     NaN         NaN            NaN        NaN       13.0
# 3            NaN     NaN         NaN            NaN        NaN        6.0
# 4            NaN     NaN         NaN            NaN        NaN        8.0
#
#   weaptype1_txt  weapsubtype1        weapsubtype1_txt  weaptype2  \
# 0       Unknown           NaN                     NaN        NaN
# 1       Unknown           NaN                     NaN        NaN
# 2       Unknown           NaN                     NaN        NaN
# 3    Explosives          16.0  Unknown Explosive Type        NaN
# 4    Incendiary           NaN                     NaN        NaN
#
#   weaptype2_txt  weapsubtype2 weapsubtype2_txt  weaptype3 weaptype3_txt  \
# 0           NaN           NaN              NaN        NaN           NaN
# 1           NaN           NaN              NaN        NaN           NaN
# 2           NaN           NaN              NaN        NaN           NaN
# 3           NaN           NaN              NaN        NaN           NaN
# 4           NaN           NaN              NaN        NaN           NaN
#
#    weapsubtype3 weapsubtype3_txt  weaptype4 weaptype4_txt  weapsubtype4  \
# 0           NaN              NaN        NaN           NaN           NaN
# 1           NaN              NaN        NaN           NaN           NaN
# 2           NaN              NaN        NaN           NaN           NaN
# 3           NaN              NaN        NaN           NaN           NaN
# 4           NaN              NaN        NaN           NaN           NaN
#
#   weapsubtype4_txt  weapdetail  nkill  nkillus  nkillter  nwound  nwoundus  \
# 0              NaN         NaN    1.0      NaN       NaN     0.0       NaN
# 1              NaN         NaN    0.0      NaN       NaN     0.0       NaN
# 2              NaN         NaN    1.0      NaN       NaN     0.0       NaN
# 3              NaN   Explosive    NaN      NaN       NaN     NaN       NaN
# 4              NaN  Incendiary    NaN      NaN       NaN     NaN       NaN
#
#    nwoundte  property  propextent propextent_txt  propvalue propcomment  \
# 0       NaN       0.0         NaN            NaN        NaN         NaN
# 1       NaN       0.0         NaN            NaN        NaN         NaN
# 2       NaN       0.0         NaN            NaN        NaN         NaN
# 3       NaN       1.0         NaN            NaN        NaN         NaN
# 4       NaN       1.0         NaN            NaN        NaN         NaN
#
#    ishostkid  nhostkid  nhostkidus  nhours  ndays divert kidhijcountry  \
# 0        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 1        1.0       1.0         0.0     NaN    NaN    NaN        Mexico
# 2        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 3        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 4        0.0       NaN         NaN     NaN    NaN    NaN           NaN
#
#    ransom  ransomamt  ransomamtus  ransompaid  ransompaidus ransomnote  \
# 0     0.0        NaN          NaN         NaN           NaN        NaN
# 1     1.0   800000.0          NaN         NaN           NaN        NaN
# 2     0.0        NaN          NaN         NaN           NaN        NaN
# 3     0.0        NaN          NaN         NaN           NaN        NaN
# 4     0.0        NaN          NaN         NaN           NaN        NaN
#
#    hostkidoutcome hostkidoutcome_txt  nreleased addnotes scite1 scite2 scite3  \
# 0             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 1             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 2             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 3             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 4             NaN                NaN        NaN      NaN    NaN    NaN    NaN
#
#   dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY related
# 0     PGIS      0.0       0.0       0.0      0.0     NaN
# 1     PGIS      0.0       1.0       1.0      1.0     NaN
# 2     PGIS     -9.0      -9.0       1.0      1.0     NaN
# 3     PGIS     -9.0      -9.0       1.0      1.0     NaN
# 4     PGIS     -9.0      -9.0       1.0      1.0     NaN

# %%
data.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.333590e+05  133359.000000  133359.000000  133359.000000
# mean   1.998025e+11    1997.960355       6.341072      15.378595
# std    1.252282e+09      12.524202       3.394693       8.822744
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.988020e+11    1988.000000       3.000000       8.000000
# 50%    1.997092e+11    1997.000000       6.000000      15.000000
# 75%    2.011013e+11    2011.000000       9.000000      23.000000
# max    2.014061e+11    2014.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  133359.000000  133359.000000  133359.000000  129078.000000
# mean        0.036338     134.569710       6.726138      22.509242
# std         0.187130     117.295785       3.010577      20.035822
# min         0.000000       4.000000       1.000000     -53.154613
# 25%         0.000000      69.000000       5.000000       8.964041
# 50%         0.000000      98.000000       6.000000      30.661385
# 75%         0.000000     160.000000      10.000000      35.120144
# max         1.000000    1004.000000      12.000000      74.633553
#
#           longitude    specificity       vicinity          crit1  \
# count  1.290770e+05  133353.000000  133359.000000  133359.000000
# mean  -6.482157e+02       1.436796       0.066272       0.987657
# std    2.398899e+05       1.027414       0.292406       0.110410
# min   -8.618590e+07       1.000000      -9.000000       0.000000
# 25%   -6.341388e+00       1.000000       0.000000       1.000000
# 50%    3.550351e+01       1.000000       0.000000       1.000000
# 75%    6.821800e+01       1.000000       0.000000       1.000000
# max    1.793667e+02       5.000000       1.000000       1.000000
#
#                crit2          crit3      doubtterr   alternative  \
# count  133359.000000  133359.000000  133358.000000  19723.000000
# mean        0.992539       0.891976      -0.782428      1.291791
# std         0.086055       0.310412       2.812102      0.612372
# min         0.000000       0.000000      -9.000000      1.000000
# 25%         1.000000       1.000000       0.000000      1.000000
# 50%         1.000000       1.000000       0.000000      1.000000
# 75%         1.000000       1.000000       0.000000      1.000000
# max         1.000000       1.000000       1.000000      5.000000
#
#             multiple        success        suicide    attacktype1  \
# count  133358.000000  133359.000000  133359.000000  133359.000000
# mean        0.122955       0.910835       0.026245       3.134989
# std         0.328386       0.284983       0.159864       1.843939
# min         0.000000       0.000000       0.000000       1.000000
# 25%         0.000000       1.000000       0.000000       2.000000
# 50%         0.000000       1.000000       0.000000       3.000000
# 75%         0.000000       1.000000       0.000000       3.000000
# max         1.000000       1.000000       1.000000       9.000000
#
#        attacktype2  attacktype3      targtype1   targsubtype1        natlty1  \
# count  3813.000000   223.000000  133359.000000  126915.000000  132454.000000
# mean      3.422764     4.636771       8.174101      46.408407     127.523895
# std       2.105463     2.227569       6.648798      31.538527      86.754354
# min       1.000000     1.000000       1.000000       1.000000       4.000000
# 25%       2.000000     2.000000       2.000000      21.000000      75.000000
# 50%       2.000000     6.000000       4.000000      34.000000     101.000000
# 75%       6.000000     7.000000      14.000000      73.000000     175.000000
# max       9.000000     7.000000      22.000000     113.000000    1004.000000
#
#          targtype2  targsubtype2      natlty2   targtype3  targsubtype3  \
# count  6904.000000   6476.000000  6599.000000  762.000000    692.000000
# mean      9.730736     52.752625   133.179421    9.371391     53.141618
# std       5.829094     25.966018   128.036619    5.883438     26.921930
# min       1.000000      1.000000     4.000000    1.000000      1.000000
# 25%       3.000000     25.000000    92.000000    3.000000     25.000000
# 50%      14.000000     67.000000    97.000000   14.000000     67.000000
# 75%      14.000000     68.000000   182.000000   14.000000     72.000000
# max      22.000000    113.000000  1004.000000   22.000000    108.000000
#
#           natlty3    guncertain1  guncertain2  guncertain3     individual  \
# count  734.000000  132978.000000   768.000000    99.000000  133358.000000
# mean   134.175749       0.098708     0.326823     0.363636       0.002197
# std    142.021905       0.298271     0.469358     0.483494       0.046822
# min      4.000000       0.000000     0.000000     0.000000       0.000000
# 25%     69.000000       0.000000     0.000000     0.000000       0.000000
# 50%     97.000000       0.000000     0.000000     0.000000       0.000000
# 75%    167.000000       0.000000     1.000000     1.000000       0.000000
# max    999.000000       1.000000     1.000000     1.000000       1.000000
#
#              nperps      nperpcap       claimed    claimmode      claim2  \
# count  62243.000000  63869.000000  67238.000000  9159.000000  703.000000
# mean     -54.989332     -2.339774     -0.062227     7.057321    0.204836
# std      283.762999     15.788720      1.380913     2.946545    1.488084
# min      -99.000000    -99.000000     -9.000000     1.000000   -9.000000
# 25%      -99.000000      0.000000      0.000000     5.000000    0.000000
# 50%      -99.000000      0.000000      0.000000     8.000000    0.000000
# 75%        1.000000      0.000000      0.000000    10.000000    1.000000
# max    25000.000000    406.000000      1.000000    10.000000    1.000000
#
#        claimmode2     claim3  claimmode3    compclaim      weaptype1  \
# count  292.000000  97.000000   58.000000  4515.000000  133358.000000
# mean     7.486301   0.577320    7.448276    -6.803101       6.375006
# std      3.224128   0.496552    3.424230     3.920453       2.097323
# min      1.000000   0.000000    1.000000    -9.000000       1.000000
# 25%      7.000000   0.000000    4.500000    -9.000000       5.000000
# 50%      9.000000   1.000000    9.000000    -9.000000       6.000000
# 75%     10.000000   1.000000   10.000000    -9.000000       6.000000
# max     10.000000   1.000000   10.000000     1.000000      13.000000
#
#        weapsubtype1    weaptype2  weapsubtype2    weaptype3  weapsubtype3  \
# count  117920.00000  8302.000000   7436.000000  1103.000000   1000.000000
# mean       10.91479     6.565406     10.611754     6.748867     11.194000
# std         6.68233     1.941686      7.503204     2.049620      8.146578
# min         1.00000     1.000000      1.000000     2.000000      2.000000
# 25%         5.00000     5.000000      5.000000     5.000000      3.000000
# 50%        12.00000     6.000000      7.000000     6.000000      7.000000
# 75%        16.00000     8.000000     18.000000     8.000000     19.000000
# max        31.00000    13.000000     31.000000    13.000000     28.000000
#
#        weaptype4  weapsubtype4          nkill       nkillus      nkillter  \
# count  73.000000     70.000000  125844.000000  68920.000000  67482.000000
# mean    6.246575     10.842857       2.268006      0.074275      0.296316
# std     1.507212      8.192672      10.772037      7.407924      3.275147
# min     5.000000      2.000000       0.000000      0.000000      0.000000
# 25%     5.000000      3.000000       0.000000      0.000000      0.000000
# 50%     6.000000      9.500000       0.000000      0.000000      0.000000
# 75%     6.000000     16.000000       2.000000      0.000000      0.000000
# max    12.000000     28.000000    1384.000000   1360.000000    500.000000
#
#               nwound      nwoundus      nwoundte       property    propextent  \
# count  121730.000000  68668.000000  66162.000000  133358.000000  48144.000000
# mean        3.232745      0.060363      0.044451      -0.257427      3.321058
# std        41.127633      3.980318      0.998406       2.840856      0.505632
# min         0.000000      0.000000      0.000000      -9.000000      1.000000
# 25%         0.000000      0.000000      0.000000       0.000000      3.000000
# 50%         0.000000      0.000000      0.000000       1.000000      3.000000
# 75%         2.000000      0.000000      0.000000       1.000000      4.000000
# max      8191.000000    751.000000    200.000000       1.000000      4.000000
#
#           propvalue      ishostkid      nhostkid   nhostkidus       nhours  \
# count  2.306800e+04  133180.000000   9055.000000  9000.000000  2667.000000
# mean   3.382889e+05       0.060287      4.042960    -0.503889   -27.368579
# std    2.015585e+07       0.365639    234.695346     8.174776    93.019175
# min   -9.900000e+01      -9.000000    -99.000000   -99.000000   -99.000000
# 25%   -9.900000e+01       0.000000      1.000000     0.000000   -99.000000
# 50%   -9.900000e+01       0.000000      1.000000     0.000000     0.000000
# 75%    2.000000e+04       0.000000      4.000000     0.000000     0.000000
# max    2.700000e+09       1.000000  17000.000000    86.000000   999.000000
#
#              ndays        ransom     ransomamt   ransomamtus    ransompaid  \
# count  5003.000000  72864.000000  1.085000e+03  2.990000e+02  5.100000e+02
# mean    -20.687388     -0.143130  3.332532e+06  1.089224e+06  5.351309e+05
# std     138.540276      1.187443  3.247390e+07  9.691238e+06  2.859938e+06
# min     -99.000000     -9.000000 -9.900000e+01 -9.900000e+01 -9.900000e+01
# 25%     -99.000000      0.000000  0.000000e+00  0.000000e+00 -9.900000e+01
# 50%       1.000000      0.000000  1.500000e+04  0.000000e+00  0.000000e+00
# 75%       5.000000      0.000000  5.000000e+05  0.000000e+00  2.475000e+04
# max    2454.000000      1.000000  1.000000e+09  1.320000e+08  4.100000e+07
#
#        ransompaidus  hostkidoutcome    nreleased        INT_LOG  \
# count    288.000000     6474.000000  5882.000000  133358.000000
# mean     426.003472        4.466172   -23.733254      -4.643134
# std     4023.185283        2.060760    59.772994       4.543728
# min      -99.000000        1.000000   -99.000000      -9.000000
# 25%        0.000000        2.000000   -99.000000      -9.000000
# 50%        0.000000        4.000000     1.000000      -9.000000
# 75%        0.000000        7.000000     2.000000       0.000000
# max    48000.000000        7.000000  1201.000000       1.000000
#
#             INT_IDEO       INT_MISC        INT_ANY
# count  133358.000000  133358.000000  133358.000000
# mean       -4.593478       0.100856      -3.983338
# std         4.608998       0.647574       4.687631
# min        -9.000000      -9.000000      -9.000000
# 25%        -9.000000       0.000000      -9.000000
# 50%        -9.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000

# %%
data.shape
# Out:
# (133359, 135)

# %%
data.isnull().sum()
# Out:
# eventid                    0
# iyear                      0
# imonth                     0
# iday                       0
# approxdate            131517
# extended                   0
# resolution            131139
# country                    0
# country_txt                0
# region                     0
# region_txt                 0
# provstate                419
# city                     434
# latitude                4281
# longitude               4282
# specificity                6
# vicinity                   0
# location               99382
# summary                66129
# crit1                      0
# crit2                      0
# crit3                      0
# doubtterr                  1
# alternative           113636
# alternative_txt       113636
# multiple                   1
# success                    0
# suicide                    0
# attacktype1                0
# attacktype1_txt            0
# attacktype2           129546
# attacktype2_txt       129546
# attacktype3           133136
# attacktype3_txt       133136
# targtype1                  0
# targtype1_txt              0
# targsubtype1            6444
# targsubtype1_txt        6444
# corp1                  42550
# target1                  636
# natlty1                  905
# natlty1_txt              905
# targtype2             126455
# targtype2_txt         126455
# targsubtype2          126883
# targsubtype2_txt      126883
# corp2                 127482
# target2               126579
# natlty2               126760
# natlty2_txt           126760
# targtype3             132597
# targtype3_txt         132597
# targsubtype3          132667
# targsubtype3_txt      132667
# corp3                 132747
# target3               132598
# natlty3               132625
# natlty3_txt           132625
# gname                      0
# gsubname              129264
# gname2                132533
# gsubname2             133276
# gname3                133256
# gsubname3             133356
# motive                 89774
# guncertain1              381
# guncertain2           132591
# guncertain3           133260
# individual                 1
# nperps                 71116
# nperpcap               69490
# claimed                66121
# claimmode             124200
# claimmode_txt         124200
# claim2                132656
# claimmode2            133067
# claimmode2_txt        133067
# claim3                133262
# claimmode3            133301
# claimmode3_txt        133301
# compclaim             128844
# weaptype1                  1
# weaptype1_txt              1
# weapsubtype1           15439
# weapsubtype1_txt       15439
# weaptype2             125057
# weaptype2_txt         125057
# weapsubtype2          125923
# weapsubtype2_txt      125923
# weaptype3             132256
# weaptype3_txt         132256
# weapsubtype3          132359
# weapsubtype3_txt      132359
# weaptype4             133286
# weaptype4_txt         133286
# weapsubtype4          133289
# weapsubtype4_txt      133289
# weapdetail             37130
# nkill                   7515
# nkillus                64439
# nkillter               65877
# nwound                 11629
# nwoundus               64691
# nwoundte               67197
# property                   1
# propextent             85215
# propextent_txt         85215
# propvalue             110291
# propcomment            96827
# ishostkid                179
# nhostkid              124304
# nhostkidus            124359
# nhours                130692
# ndays                 128356
# divert                133080
# kidhijcountry         130071
# ransom                 60495
# ransomamt             132274
# ransomamtus           133060
# ransompaid            132849
# ransompaidus          133071
# ransomnote            133029
# hostkidoutcome        126885
# hostkidoutcome_txt    126885
# nreleased             127477
# addnotes              117145
# scite1                 66192
# scite2                 85981
# scite3                107023
# dbsource                   1
# INT_LOG                    1
# INT_IDEO                   1
# INT_MISC                   1
# INT_ANY                    1
# related               116956
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133359 entries, 0 to 133358
# Columns: 135 entries, eventid to related
# dtypes: float64(62), int64(15), object(58)
# memory usage: 137.4+ MB

# %%
plt.figure(figsize=(20,5))
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
pd.set_option('display.width',None)
data.isnull().sum()
# Out:
# eventid                    0
# iyear                      0
# imonth                     0
# iday                       0
# approxdate            131517
# extended                   0
# resolution            131139
# country                    0
# country_txt                0
# region                     0
# region_txt                 0
# provstate                419
# city                     434
# latitude                4281
# longitude               4282
# specificity                6
# vicinity                   0
# location               99382
# summary                66129
# crit1                      0
# crit2                      0
# crit3                      0
# doubtterr                  1
# alternative           113636
# alternative_txt       113636
# multiple                   1
# success                    0
# suicide                    0
# attacktype1                0
# attacktype1_txt            0
# attacktype2           129546
# attacktype2_txt       129546
# attacktype3           133136
# attacktype3_txt       133136
# targtype1                  0
# targtype1_txt              0
# targsubtype1            6444
# targsubtype1_txt        6444
# corp1                  42550
# target1                  636
# natlty1                  905
# natlty1_txt              905
# targtype2             126455
# targtype2_txt         126455
# targsubtype2          126883
# targsubtype2_txt      126883
# corp2                 127482
# target2               126579
# natlty2               126760
# natlty2_txt           126760
# targtype3             132597
# targtype3_txt         132597
# targsubtype3          132667
# targsubtype3_txt      132667
# corp3                 132747
# target3               132598
# natlty3               132625
# natlty3_txt           132625
# gname                      0
# gsubname              129264
# gname2                132533
# gsubname2             133276
# gname3                133256
# gsubname3             133356
# motive                 89774
# guncertain1              381
# guncertain2           132591
# guncertain3           133260
# individual                 1
# nperps                 71116
# nperpcap               69490
# claimed                66121
# claimmode             124200
# claimmode_txt         124200
# claim2                132656
# claimmode2            133067
# claimmode2_txt        133067
# claim3                133262
# claimmode3            133301
# claimmode3_txt        133301
# compclaim             128844
# weaptype1                  1
# weaptype1_txt              1
# weapsubtype1           15439
# weapsubtype1_txt       15439
# weaptype2             125057
# weaptype2_txt         125057
# weapsubtype2          125923
# weapsubtype2_txt      125923
# weaptype3             132256
# weaptype3_txt         132256
# weapsubtype3          132359
# weapsubtype3_txt      132359
# weaptype4             133286
# weaptype4_txt         133286
# weapsubtype4          133289
# weapsubtype4_txt      133289
# weapdetail             37130
# nkill                   7515
# nkillus                64439
# nkillter               65877
# nwound                 11629
# nwoundus               64691
# nwoundte               67197
# property                   1
# propextent             85215
# propextent_txt         85215
# propvalue             110291
# propcomment            96827
# ishostkid                179
# nhostkid              124304
# nhostkidus            124359
# nhours                130692
# ndays                 128356
# divert                133080
# kidhijcountry         130071
# ransom                 60495
# ransomamt             132274
# ransomamtus           133060
# ransompaid            132849
# ransompaidus          133071
# ransomnote            133029
# hostkidoutcome        126885
# hostkidoutcome_txt    126885
# nreleased             127477
# addnotes              117145
# scite1                 66192
# scite2                 85981
# scite3                107023
# dbsource                   1
# INT_LOG                    1
# INT_IDEO                   1
# INT_MISC                   1
# INT_ANY                    1
# related               116956
# dtype: int64

# %%
data.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
#        'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2',
#        'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed',
#        'claimmode', 'claimmode_txt', 'claim2', 'claimmode2',
#        'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt',
#        'compclaim', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'weapsubtype2',
#        'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt', 'weapsubtype3',
#        'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4',
#        'weapsubtype4_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent',
#        'propextent_txt', 'propvalue', 'propcomment', 'ishostkid',
#        'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'divert',
#        'kidhijcountry', 'ransom', 'ransomamt', 'ransomamtus',
#        'ransompaid', 'ransompaidus', 'ransomnote', 'hostkidoutcome',
#        'hostkidoutcome_txt', 'nreleased', 'addnotes', 'scite1', 'scite2',
#        'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY',
#        'related'], dtype=object)

# %%
datanew=data[['iyear' , 'imonth','iday','country_txt','provstate','region_txt','city','latitude','longitude',
         'attacktype1_txt','nkill','nwound','target1','summary','gname','targtype1_txt','weaptype1_txt','motive']]

# %%
datanew.rename(columns={'iyear':'YEAR','imonth':'MONTH','iday':"DAY",'gname':'GROUP','country_txt':'COUNTRY','region_txt':'REGION','provstate':'STATE','attacktype1_txt':'ATTACK_TYPE','targtype1_txt':'TARGET_TYPE','weaptype1_txt':'WEAPON','nkill':'KILL',
     'nwound':'WOUND'},inplace=True)
datanew.head()
# Out:
#    YEAR  MONTH  DAY             COUNTRY    STATE                       REGION  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             city   latitude   longitude                     ATTACK_TYPE  KILL  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination   1.0
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)   0.0
# 2        Unknown  15.478598  120.599741                   Assassination   1.0
# 3         Athens  37.997490   23.762728               Bombing/Explosion   NaN
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack   NaN
#
#    WOUND                  target1 summary                               GROUP  \
# 0    0.0             Julio Guzman     NaN                              MANO-D
# 1    0.0  Nadine Chaval, daughter     NaN  23rd of September Communist League
# 2    0.0                 Employee     NaN                             Unknown
# 3    NaN             U.S. Embassy     NaN                             Unknown
# 4    NaN           U.S. Consulate     NaN                             Unknown
#
#                    TARGET_TYPE      WEAPON motive
# 0  Private Citizens & Property     Unknown    NaN
# 1      Government (Diplomatic)     Unknown    NaN
# 2          Journalists & Media     Unknown    NaN
# 3      Government (Diplomatic)  Explosives    NaN
# 4      Government (Diplomatic)  Incendiary    NaN

# %%
datanew.isnull().sum()
# Out:
# YEAR               0
# MONTH              0
# DAY                0
# COUNTRY            0
# STATE            419
# REGION             0
# city             434
# latitude        4281
# longitude       4282
# ATTACK_TYPE        0
# KILL            7515
# WOUND          11629
# target1          636
# summary        66129
# GROUP              0
# TARGET_TYPE        0
# WEAPON             1
# motive         89774
# dtype: int64

# %%
datanew.shape
# Out:
# (133359, 18)

# %%
datanew['WOUND'] = datanew['WOUND'].fillna(0)
datanew['KILL'] = datanew['KILL'].fillna(0)
datanew['GROUP'] = datanew['GROUP'].fillna(0)

# %%
datanew['COUNTRY'].value_counts().idxmax()  #most number of attacks
# Out:
# 'Iraq'

# %%
datanew['REGION'].value_counts().idxmax()   #most number of attacks
# Out:
# 'Middle East & North Africa'

# %%
datanew['YEAR'].value_counts().idxmax()     #most number of attacks
# Out:
# 2013

# %%
datanew['MONTH'].value_counts().idxmax()    #most number of attacks
# Out:
# 5

# %%
datanew['GROUP'].value_counts().idxmax()
# Out:
# 'Unknown'

# %%
datanew['ATTACK_TYPE'].value_counts().idxmax()  #Type of attacks
# Out:
# 'Bombing/Explosion'

# %%
datanew['YEAR'].unique()
# Out:
# array([1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980,
#        1981, 1986, 1982, 1983, 1984, 1985, 1987, 1988, 1989, 1990, 1991,
#        1992, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014])

# %%
y = datanew['YEAR'].value_counts(dropna = False).sort_index()
y
# Out:
# 1970      651
# 1971      471
# 1972      568
# 1973      473
# 1974      581
# 1975      740
# 1976      923
# 1977     1319
# 1978     1526
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 1983     2870
# 1984     3495
# 1985     2915
# 1986     2860
# 1987     3183
# 1988     3721
# 1989     4324
# 1990     3887
# 1991     4683
# 1992     5071
# 1994     3456
# 1995     3081
# 1996     3058
# 1997     3197
# 1998      934
# 1999     1395
# 2000     1814
# 2001     1906
# 2002     1333
# 2003     1278
# 2004     1166
# 2005     2017
# 2006     2758
# 2007     3242
# 2008     4805
# 2009     4721
# 2010     4826
# 2011     5076
# 2012     8522
# 2013    12036
# 2014     8023
# Name: YEAR, dtype: int64

# %%
plt.figure(figsize = (16,10))
sns.barplot(x = datanew['YEAR'].unique(),y = datanew['YEAR'].value_counts(dropna = False).sort_index(),palette = "ch:s=.25,rot=-.25")
plt.xticks(rotation = 50)
plt.xlabel('Year of attacks',fontsize=14)
plt.ylabel('Number of attacks',fontsize=14)
plt.title('Attacks In Years',fontsize=22)
plt.show()

# %%
pd.crosstab(datanew.YEAR, datanew.REGION).plot(kind='area',stacked=False,figsize=(18,10))
plt.title('Terrorist Activities By Region In Each Year',fontsize=24)
plt.ylabel('Number of Attacks',fontsize=18)
plt.xlabel("Year",fontsize=18)
plt.show()

# %%
country = datanew.COUNTRY.value_counts()[:10]
country
# Out:
# Iraq              14406
# Pakistan          10491
# India              8672
# Colombia           7805
# Afghanistan        6723
# Peru               6070
# El Salvador        5320
# United Kingdom     4837
# Philippines        4521
# Spain              3237
# Name: COUNTRY, dtype: int64

# %%
datanew['city'].value_counts().to_frame().sort_values('city',axis=0,ascending=False).head(15).plot(kind='bar',figsize=(18,5), color='red')
plt.xticks(rotation = 45)
plt.xlabel("Cities",fontsize=15)
plt.ylabel("Number of Attacks",fontsize=15)
plt.title("Top 10 Most Effected City",fontsize=20)
plt.show()

# %%
datanew[['ATTACK_TYPE','KILL']].groupby(["ATTACK_TYPE"],axis=0).sum().plot(kind='bar',figsize=(20,10),color=['y'])
plt.xticks(rotation=50)
plt.title("Number of killed (by attack type) ",fontsize=25)
plt.ylabel('Number of people',fontsize=15)
plt.xlabel('Attack type',fontsize=15)
plt.xticks(rotation= 90, fontsize = 16)
plt.show()

# %%
datanew[['ATTACK_TYPE','WOUND']].groupby(["ATTACK_TYPE"],axis=0).sum().plot(kind='bar',figsize=(20,10),color=['r'])
plt.xticks(rotation=50)
plt.title("Number of wounded  ",fontsize=25)
plt.ylabel('Number of people',fontsize=18)
plt.xlabel('Attack type',fontsize=18)
plt.xticks(rotation= 90, fontsize = 18)
plt.show()

# %%
datanew[['GROUP','KILL']].groupby(['GROUP'],axis=0).sum().drop('Unknown').sort_values('KILL',ascending=False).head(10).plot(kind='bar',color='blue',figsize=(20,10))
plt.title("Top 10 terrorist group attack",fontsize=25)
plt.xlabel("terrorist group name",fontsize=22)
plt.ylabel("No of killed people",fontsize=22)
plt.xticks(rotation= 90, fontsize = 18)
plt.show()

# %%
fatality=datanew[['YEAR','KILL']].groupby(['YEAR']).sum()
fig,ax4 = plt.subplots(figsize=(18,10))
fatality.plot(kind='bar',alpha=0.7,ax=ax4, color='g')
plt.xticks(rotation = 90)
plt.title("PEOPLE DIED DUE TO ATTACK YEAR WISE",fontsize=20)
plt.ylabel("Number of people killed",fontsize=16)
plt.xlabel('Year',fontsize=16)
plt.show()

# %%
terrorism=datanew[['GROUP','COUNTRY','KILL']]
terrorism=terrorism.groupby(['GROUP','COUNTRY'],axis=0).sum().sort_values('KILL',ascending=False).drop('Unknown').reset_index().head(12)
terrorism
# Out:
#                                                GROUP      COUNTRY     KILL
# 0                                  Shining Path (SL)         Peru  11575.0
# 1                                            Taliban  Afghanistan  11461.0
# 2            Liberation Tigers of Tamil Eelam (LTTE)    Sri Lanka  10928.0
# 3   Farabundo Marti National Liberation Front (FMLN)  El Salvador   8019.0
# 4                                         Boko Haram      Nigeria   7256.0
# 5                  Nicaraguan Democratic Force (FDN)    Nicaragua   6630.0
# 6      Revolutionary Armed Forces of Colombia (FARC)     Colombia   5547.0
# 7                    Tehrik-i-Taliban Pakistan (TTP)     Pakistan   4543.0
# 8                                   Al-Qaida in Iraq         Iraq   4273.0
# 9                            New People's Army (NPA)  Philippines   3769.0
# 10                    Kurdistan Workers' Party (PKK)       Turkey   3759.0
# 11       Islamic State of Iraq and the Levant (ISIL)         Iraq   3229.0

# %%
total_kill = datanew.loc[:,'KILL']
print('Total number of people killed by terrorist attack is', int(sum(total_kill.dropna())))
# Out:
# Total number of people killed by terrorist attack is 285415

# %%
kill_type = datanew.pivot_table(columns='ATTACK_TYPE', values='KILL', aggfunc='sum')
kill_type
# Out:
# ATTACK_TYPE  Armed Assault  Assassination  Bombing/Explosion  \
# KILL              125928.0        21446.0           103955.0
#
# ATTACK_TYPE  Facility/Infrastructure Attack  Hijacking  \
# KILL                                 2948.0     3603.0
#
# ATTACK_TYPE  Hostage Taking (Barricade Incident)  Hostage Taking (Kidnapping)  \
# KILL                                      2326.0                       7612.0
#
# ATTACK_TYPE  Unarmed Assault  Unknown
# KILL                   727.0  16870.0

# %%
Kill_wrt_country = datanew.pivot_table(columns='COUNTRY', values='KILL', aggfunc='sum')
Kill_wrt_country
# Out:
# COUNTRY  Afghanistan  Albania  Algeria  Andorra  Angola  Antigua and Barbuda  \
# KILL         17454.0     41.0  11008.0      0.0  3036.0                  0.0
#
# COUNTRY  Argentina  Armenia  Australia  Austria  Azerbaijan  Bahamas  Bahrain  \
# KILL         490.0     31.0       13.0     28.0       252.0      1.0     29.0
#
# COUNTRY  Bangladesh  Barbados  Belarus  Belgium  Belize  Benin  Bhutan  \
# KILL         1039.0      76.0     14.0     41.0     3.0    0.0     9.0
#
# COUNTRY  Bolivia  Bosnia-Herzegovina  Botswana  Brazil  Brunei  Bulgaria  \
# KILL        42.0                75.0      11.0   199.0     0.0      28.0
#
# COUNTRY  Burkina Faso  Burundi  Cambodia  Cameroon  Canada  \
# KILL              3.0   3884.0     543.0     145.0   354.0
#
# COUNTRY  Central African Republic   Chad  Chile  China  Colombia  Comoros  \
# KILL                        778.0  723.0  225.0  645.0   14389.0      1.0
#
# COUNTRY  Costa Rica  Croatia  Cuba  Cyprus  Czech Republic  Czechoslovakia  \
# KILL           17.0    248.0   8.0    45.0             6.0            27.0
#
# COUNTRY  Democratic Republic of the Congo  Denmark  Djibouti  Dominica  \
# KILL                               2243.0      2.0     274.0       3.0
#
# COUNTRY  Dominican Republic  East Germany (GDR)  East Timor  Ecuador   Egypt  \
# KILL                   32.0                 2.0         9.0     53.0  1317.0
#
# COUNTRY  El Salvador  Equatorial Guinea  Eritrea  Estonia  Ethiopia  \
# KILL         12053.0                2.0     46.0      3.0    1371.0
#
# COUNTRY  Falkland Islands  Fiji  Finland  France  French Guiana  \
# KILL                  0.0   8.0      9.0   269.0            1.0
#
# COUNTRY  French Polynesia  Gabon  Gambia  Georgia  Germany  Ghana  Greece  \
# KILL                  0.0    6.0    13.0    277.0     55.0   19.0   258.0
#
# COUNTRY  Grenada  Guadeloupe  Guatemala  Guinea  Guinea-Bissau  Guyana  Haiti  \
# KILL         9.0         8.0     5167.0   211.0           17.0    41.0  329.0
#
# COUNTRY  Honduras  Hong Kong  Hungary  Iceland    India  Indonesia  \
# KILL        303.0        4.0      6.0      0.0  17751.0     1160.0
#
# COUNTRY  International    Iran     Iraq  Ireland  Israel  Italy  Ivory Coast  \
# KILL               1.0  1572.0  42050.0    115.0  1617.0  419.0        229.0
#
# COUNTRY  Jamaica  Japan  Jordan  Kazakhstan   Kenya  Kosovo  Kuwait  \
# KILL        42.0   47.0    86.0        29.0  1231.0    82.0    34.0
#
# COUNTRY  Kyrgyzstan  Laos  Latvia  Lebanon  Lesotho  Liberia  Libya  \
# KILL            8.0  23.0     2.0   3849.0     45.0    177.0  556.0
#
# COUNTRY  Lithuania  Luxembourg  Macau  Macedonia  Madagascar  Malawi  \
# KILL           1.0         0.0    1.0       49.0        28.0    33.0
#
# COUNTRY  Malaysia  Maldives   Mali  Malta  Martinique  Mauritania  Mauritius  \
# KILL        140.0      19.0  580.0    4.0         0.0        43.0        0.0
#
# COUNTRY  Mexico  Moldova  Montenegro  Morocco  Mozambique  Myanmar  Namibia  \
# KILL      744.0     13.0         1.0    292.0      2607.0    918.0    220.0
#
# COUNTRY   Nepal  Netherlands  New Caledonia  New Hebrides  New Zealand  \
# KILL     1960.0         36.0           35.0           0.0          1.0
#
# COUNTRY  Nicaragua  Niger  Nigeria  North Korea  North Yemen  Norway  \
# KILL       10593.0  459.0   9785.0          3.0          3.0    79.0
#
# COUNTRY  Pakistan  Panama  Papua New Guinea  Paraguay  \
# KILL      18761.0    38.0              79.0      28.0
#
# COUNTRY  People's Republic of the Congo     Peru  Philippines  Poland  \
# KILL                               15.0  12742.0       7921.0     9.0
#
# COUNTRY  Portugal  Qatar  Republic of the Congo  Rhodesia  Romania  Russia  \
# KILL         32.0    7.0                  151.0     217.0      4.0  4112.0
#
# COUNTRY  Rwanda  Saudi Arabia  Senegal  Serbia  Serbia-Montenegro  Seychelles  \
# KILL     3234.0         249.0    318.0     3.0                3.0         0.0
#
# COUNTRY  Sierra Leone  Singapore  Slovak Republic  Slovenia  Solomon Islands  \
# KILL            839.0        5.0              7.0       1.0              4.0
#
# COUNTRY  Somalia  South Africa  South Korea  South Sudan  South Vietnam  \
# KILL      4413.0        2620.0         10.0       1016.0           81.0
#
# COUNTRY  South Yemen  Soviet Union   Spain  Sri Lanka  St. Kitts and Nevis  \
# KILL             0.0          96.0  1267.0    15523.0                  0.0
#
# COUNTRY  St. Lucia   Sudan  Suriname  Swaziland  Sweden  Switzerland   Syria  \
# KILL           2.0  3187.0      29.0        6.0    13.0         74.0  4305.0
#
# COUNTRY  Taiwan  Tajikistan  Tanzania  Thailand  Togo  Trinidad and Tobago  \
# KILL       60.0       292.0      48.0    2360.0  76.0                  6.0
#
# COUNTRY  Tunisia  Turkey  Turkmenistan  Uganda  Ukraine  United Arab Emirates  \
# KILL       140.0  5145.0           3.0  2881.0    292.0                 122.0
#
# COUNTRY  United Kingdom  United States  Uruguay  Uzbekistan  Vanuatu  \
# KILL             3358.0         3547.0      5.0        68.0      0.0
#
# COUNTRY  Vatican City  Venezuela  Vietnam  Wallis and Futuna  \
# KILL              0.0      212.0      1.0                0.0
#
# COUNTRY  West Bank and Gaza Strip  West Germany (FRG)  Western Sahara   Yemen  \
# KILL                       1186.0                97.0             1.0  3274.0
#
# COUNTRY  Yugoslavia  Zaire  Zambia  Zimbabwe
# KILL          119.0  324.0    70.0     154.0

# %% [markdown]
# **TOTAL DEATHS - 438**
